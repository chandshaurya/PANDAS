# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\powerbi\\projects\\electricity.csv",na_values=[" "])
df.head(5)
# Out:
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16            23               2           6        1          0     10
# 1   19            22               2           3        1          0      5
# 2    7            20               2           6        7          0      7
# 3    7            22               3          21        1          0      6
# 4   11            23               2          11        1          0      2
#
#         City                                    Company  MonthlyHours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    TariffRate  ElectricityBill
# 0         8.4           3225.6
# ...

# %%
df.dropna()
df.head(5)
# Out:
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16            23               2           6        1          0     10
# 1   19            22               2           3        1          0      5
# 2    7            20               2           6        7          0      7
# 3    7            22               3          21        1          0      6
# 4   11            23               2          11        1          0      2
#
#         City                                    Company  MonthlyHours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    TariffRate  ElectricityBill
# 0         8.4           3225.6
# ...

# %%
df.shape
# Out:
# (45345, 12)

# %%
df.columns
# Out:
# Index(['Fan', 'Refrigerator', 'AirConditioner', 'Television', 'Monitor',
#        'MotorPump', 'Month', 'City', 'Company', 'MonthlyHours', 'TariffRate',
#        'ElectricityBill'],
#       dtype='object')

# %%
df.ElectricityBill.mean()
# Out:
# 4311.771306649024

# %%
df.TariffRate.mean()
# Out:
# 8.369648252288012

# %%
df.MonthlyHours.mean()
# Out:
# 515.0832065277318

# %%
df.City.nunique()
# Out:
# 16

# %%
df.Company.nunique()
# Out:
# 32

# %%
df[['City', 'Company', 'MonthlyHours', 'TariffRate','ElectricityBill']][df.ElectricityBill==df.ElectricityBill.max()]
# Out:
#               City                          Company  MonthlyHours  TariffRate  \
# 23282  Navi Mumbai  Unitech Power Transmission Ltd.           891         9.3
#
#        ElectricityBill
# 23282           8286.3

# %%
df[['City', 'Company', 'MonthlyHours', 'TariffRate','ElectricityBill']][df.ElectricityBill==df.ElectricityBill.min()]
# Out:
#            City                          Company  MonthlyHours  TariffRate  \
# 3480  New Delhi  L&T Transmission & Distribution            95         8.5
#
#       ElectricityBill
# 3480            807.5

# %%
df[['City', 'Company', 'MonthlyHours', 'TariffRate','ElectricityBill']][df.TariffRate==df.TariffRate.max()]
# Out:
#               City                                            Company  \
# 49     Navi Mumbai       Ringfeder Power Transmission India Pvt. Ltd.
# 53     Navi Mumbai                                    Power Grid Corp
# 69     Navi Mumbai                    Unitech Power Transmission Ltd.
# 101    Navi Mumbai                                   Jaiprakash Power
# 103    Navi Mumbai          Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)
# ...            ...                                                ...
# 45254  Navi Mumbai  Optibelt Power Transmission India Private Limited
# 45282  Navi Mumbai                                    Kalpataru Power
# 45289  Navi Mumbai                                          SJVN Ltd.
# 45294  Navi Mumbai                                   Sunil Hitech Eng
# 45309  Navi Mumbai                                   Adani Power Ltd.
#
#        MonthlyHours  TariffRate  ElectricityBill
# 49              577         9.3           5366.1
# ...

# %%
df.describe()
# Out:
#                 Fan  Refrigerator  AirConditioner    Television       Monitor  \
# count  45345.000000  45345.000000    45345.000000  45345.000000  45345.000000
# mean      13.990694     21.705458        1.503959     12.502635      2.865057
# std        5.470816      1.672575        1.115482      5.756007      3.894933
# min        5.000000     17.000000        0.000000      3.000000      1.000000
# 25%        9.000000     22.000000        1.000000      7.000000      1.000000
# 50%       14.000000     22.000000        2.000000     13.000000      1.000000
# 75%       19.000000     23.000000        2.000000     17.000000      1.000000
# max       23.000000     23.000000        3.000000     22.000000     12.000000
#
#        MotorPump         Month  MonthlyHours    TariffRate  ElectricityBill
# count    45345.0  45345.000000  45345.000000  45345.000000     45345.000000
# mean         0.0      6.488058    515.083207      8.369648      4311.771307
# ...

# %%
g1= df.groupby("City")

# %%
g1.max()
# Out:
#              Fan  Refrigerator  AirConditioner  Television  Monitor  \
# City
# Ahmedabad     23            23               3          22       12
# Chennai       23            23               3          22       12
# Dahej         23            23               3          22       12
# Faridabad     23            23               3          22       12
# Gurgaon       23            23               3          22       12
# Hyderabad     23            23               3          22       12
# Kolkata       23            23               3          22       12
# Mumbai        23            23               3          22       12
# Nagpur        23            23               3          22       12
# Navi Mumbai   23            23               3          22       12
# New Delhi     23            23               3          22       12
# Noida         23            23               3          22       12
# Pune          23            23               3          22       12
# ...

# %%
g1.ElectricityBill.mean()
# Out:
# City
# Ahmedabad      4045.516179
# Chennai        4545.783769
# Dahej          3880.245870
# Faridabad      4166.154168
# Gurgaon        4300.230577
# Hyderabad      4304.749211
# Kolkata        4505.428358
# Mumbai         4770.510330
# Nagpur         4613.464808
# Navi Mumbai    4782.820213
# New Delhi      4382.525983
# Noida          4201.300680
# Pune           4689.806420
# Ratnagiri      3807.397234
# Shimla         3964.076331
# Vadodara       4022.401543
# Name: ElectricityBill, dtype: float64

# %%
g1.describe()
# Out:
#                 Fan                                                   \
#               count       mean       std  min  25%   50%   75%   max
# City
# Ahmedabad    2868.0  13.935844  5.467607  5.0  9.0  14.0  19.0  23.0
# Chennai      2834.0  14.029993  5.417105  5.0  9.0  14.0  19.0  23.0
# Dahej        2821.0  13.675647  5.485578  5.0  9.0  14.0  18.0  23.0
# Faridabad    2891.0  14.015566  5.535238  5.0  9.0  14.0  19.0  23.0
# Gurgaon      2878.0  14.168172  5.494479  5.0  9.0  14.0  19.0  23.0
# Hyderabad    2914.0  13.815717  5.430206  5.0  9.0  14.0  19.0  23.0
# Kolkata      2740.0  14.015328  5.440016  5.0  9.0  14.0  19.0  23.0
# Mumbai       2846.0  14.108573  5.445156  5.0  9.0  14.0  19.0  23.0
# Nagpur       2816.0  14.104048  5.547358  5.0  9.0  14.0  19.0  23.0
# Navi Mumbai  2914.0  13.901510  5.428964  5.0  9.0  14.0  18.0  23.0
# New Delhi    2848.0  14.016503  5.429312  5.0  9.0  14.0  19.0  23.0
# ...

# %%
g2= df.groupby("Company")

# %%
g2.ElectricityBill.mean()
# Out:
# Company
# Adani Power Ltd.                                                      4303.265357
# Bonfiglioli Transmission Pvt. Ltd.                                    4313.741685
# CESC                                                                  4282.838376
# GE T&D India Limited                                                  4298.161321
# Guj Ind Power                                                         4324.300745
# Indowind Energy                                                       4371.806065
# JSW Energy Ltd.                                                       4275.249289
# Jaiprakash Power                                                      4301.149787
# Jyoti Structure                                                       4308.091721
# KEC International                                                     4363.597989
# Kalpataru Power                                                       4362.641209
# ...

# %%
g2.ElectricityBill.max()
# Out:
# Company
# Adani Power Ltd.                                                      8016.6
# Bonfiglioli Transmission Pvt. Ltd.                                    7534.8
# CESC                                                                  7387.0
# GE T&D India Limited                                                  7875.2
# Guj Ind Power                                                         7702.8
# Indowind Energy                                                       7807.8
# JSW Energy Ltd.                                                       7577.9
# Jaiprakash Power                                                      7764.8
# Jyoti Structure                                                       8230.5
# KEC International                                                     7858.7
# Kalpataru Power                                                       7826.0
# L&T Transmission & Distribution                                       7725.6
# ...

# %%
g2.TariffRate.mean()
# Out:
# Company
# Adani Power Ltd.                                                      8.345929
# Bonfiglioli Transmission Pvt. Ltd.                                    8.365155
# CESC                                                                  8.334908
# GE T&D India Limited                                                  8.381074
# Guj Ind Power                                                         8.370935
# Indowind Energy                                                       8.338628
# JSW Energy Ltd.                                                       8.370955
# Jaiprakash Power                                                      8.383949
# Jyoti Structure                                                       8.360259
# KEC International                                                     8.366436
# Kalpataru Power                                                       8.375618
# L&T Transmission & Distribution                                       8.357906
# ...

# %%
df.reset_index(drop=True, inplace=True)
df.set_index('City',inplace=True)
df.head(10)
# Out:
#            Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  \
# City
# Hyderabad   16            23               2           6        1          0
# Vadodara    19            22               2           3        1          0
# Shimla       7            20               2           6        7          0
# Mumbai       7            22               3          21        1          0
# Mumbai      11            23               2          11        1          0
# Ratnagiri   13            22               0          18        1          0
# New Delhi   23            22               3          20       12          0
# New Delhi   22            23               0          21        1          0
# New Delhi    8            20               2           8        1          0
# Dahej       10            23               0          18        7          0
#
#            Month                                    Company  MonthlyHours  \
# City
# ...

# %%
df.loc['Mumbai']
# Out:
#         Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  \
# City
# Mumbai    7            22               3          21        1          0
# Mumbai   11            23               2          11        1          0
# Mumbai    5            19               2          20        1          0
# Mumbai   23            23               0          15        1          0
# Mumbai   23            23               0           9        1          0
# ...     ...           ...             ...         ...      ...        ...
# Mumbai    9            17               1           8        1          0
# Mumbai    8            20               0          12        7          0
# Mumbai    9            21               0          22        1          0
# Mumbai    7            21               2          20        7          0
# Mumbai   23            22               1          18        1          0
#
#         Month                                            Company  \
# ...
