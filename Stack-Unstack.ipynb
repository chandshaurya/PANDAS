# %%
import pandas as pd

# %%
df= pd.read_excel("C:\\Users\\SHAURYA CHAND\\Downloads\\stocks.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack()
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
#   Microsoft                NaT    69.0                          30.56
# ...

# %%
df_stacked = df.stack(level=0)
df_stacked
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\1696044855.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df.stack(level=0)
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
# ...

# %%
df_stacked.unstack()
# Out:
#   Company                                                  Facebook  \
#     Price Price to earnings ratio (P/E) Unnamed: 0_level_0    Price
# 0     NaT                           NaT         2017-06-05    155.0
# 1     NaT                           NaT         2017-06-06    150.0
# 2     NaT                           NaT         2017-06-07    153.0
# 3     NaT                           NaT         2017-06-08    155.0
# 4     NaT                           NaT         2017-06-09    156.0
#
#                                                     Google  \
#   Price to earnings ratio (P/E) Unnamed: 0_level_0   Price
# 0                         37.10                NaN   955.0
# 1                         36.98                NaN   987.0
# 2                         36.78                NaN   963.0
# 3                         36.11                NaN  1000.0
# 4                         37.07                NaN  1012.0
#
#                                                    Microsoft  \
# ...

# %%
df= pd.read_excel("C:\\Users\\SHAURYA CHAND\\Downloads\\stocks_3_levels.xlsx",header=[0,1,2])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df= pd.read_excel("C:\\Users\\SHAURYA CHAND\\Downloads\\stocks.xlsx",header=[0,1])
df
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...

# %%
df.stack()
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...

# %%
df.stack(level=0)
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\4116294391.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)
#                      Unnamed: 0_level_1    Price                    \
#                                 Company Facebook  Google Microsoft
# 0 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    155.0   955.0      66.0
#   Unnamed: 0_level_0            Q1 2016      NaN     NaN       NaN
# 1 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    150.0   987.0      69.0
#   Unnamed: 0_level_0            Q2 2016      NaN     NaN       NaN
# 2 Income Statement                  NaN      NaN     NaN       NaN
# ...

# %%
df.stack(level=2)
# Out:
# C:\Users\SHAURYA CHAND\AppData\Local\Temp\ipykernel_257964\4116472115.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=2)
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...
